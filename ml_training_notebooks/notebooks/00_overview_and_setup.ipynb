# %% [markdown]
# # NemuParfang Training Setup
#
# Notebook pembuka untuk validasi environment, path, dan dataset sebelum masuk ke fase eksperimen.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve().parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

from src.config import ensure_directories, dataset_path, load_environment

ensure_directories()
settings = load_environment()
data_path = dataset_path()

print('Project root:', PROJECT_ROOT)
print('Dataset path:', data_path)
print('Pinecone index:', settings.index_name)
print('Dataset exists:', data_path.exists())
# Out:
# Project root: C:\porto\NemuParfang\ml_training_notebooks
# Dataset path: C:\porto\NemuParfang\ml_training_notebooks\data\raw\fra_perfumes.csv
# Pinecone index: nemuparfang-perfumes
# Dataset exists: True

# %% [markdown]
# ## Checklist
#
# - Pastikan `.env` sudah dibuat dari `.env.example`.
# - Pastikan dataset sudah ditaruh di `data/raw/`.
# - Jalankan notebook berikutnya setelah semua validasi lolos.
